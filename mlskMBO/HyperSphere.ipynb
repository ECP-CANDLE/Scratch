# %%
load_ext Cython
# Out:
# The Cython extension is already loaded. To reload it, use:
#   %reload_ext Cython

# %%
# %%cython --annotate --compile-args=-fopenmp --link-args=-gomp
#
# import numpy as np
#
# import cython
# from cython.parallel import prange
# cimport openmp
#
# cimport numpy as np
# from libc.math cimport sin, cos, pi
#
# #FLOAT64 = np.float64
# ctypedef np.float64_t FLOAT64_t
#
# @cython.boundscheck(False)
# @cython.initializedcheck(False)  # turn off negative index wrapping for entire function
# def initialize_trig_values(int dim,
#                            np.ndarray zeta,
#                            np.ndarray cos_zeta,
#                            np.ndarray sin_zeta):
#
#     cdef FLOAT64_t [:, :] z = zeta
#     cdef FLOAT64_t [:, :] C = cos_zeta
#     cdef FLOAT64_t [:, :] S = sin_zeta
#     cdef int i, j
#
#     with nogil:
#         for i in prange(dim):
#             for j in prange(i):
#                 C[i,j] = cos(z[i,j])
#                 S[i,j] = sin(z[i,j])
#
#
# @cython.boundscheck(False)
# @cython.initializedcheck(False)  # wraparound: turn off negative index wrapping for entire function
# def HyperSphere_lower_triangular(np.ndarray L_arr,
#                                  int dim,
#                                  np.ndarray cos_zeta,
#                                  np.ndarray sin_zeta):
#
#     #cdef np.ndarray L_arr = np.zeros((dim, dim), dtype=FLOAT64)
#     # Memoryviews of the numpy arrays
#     cdef FLOAT64_t [:, :] L = L_arr
#     cdef FLOAT64_t [:, :] C = cos_zeta
#     cdef FLOAT64_t [:, :] S = sin_zeta
#
#     cdef int r, s, j
#     cdef FLOAT64_t L_rs
#
#     with nogil:
#         L[0,0] = 1.0
#         for r in prange(dim):
#             L_rs = 1.0
#             for j in prange(r):
#                 L_rs *= S[r,j]
#             L[r,r] = L_rs
#             for s in prange(r):
#                 L_rs = C[r,s]
#                 for j in prange(s):
#                     L_rs *= S[r,j]
#                 L[r,s] = L_rs
#     #return L_arr
#
#
# @cython.boundscheck(False)
# @cython.initializedcheck(False)  # turn off negative index wrapping for entire function
# def HyperSphere_lower_triangular_derivative(np.ndarray dL_arr,
#                                             int dim,
#                                             int dr,
#                                             int ds,
#                                             np.ndarray cos_zeta,
#                                             np.ndarray sin_zeta):
#     # Memoryviews of the numpy arrays
#     cdef FLOAT64_t [:, :] dL = dL_arr
#     cdef FLOAT64_t [:, :] C = cos_zeta
#     cdef FLOAT64_t [:, :] S = sin_zeta
#
#     cdef FLOAT64_t dL_drs
#     cdef int r, s, j
#
#     with nogil:
#         for s in prange(dr):
#             if ds <= s:
#                 dL_drs = C[dr,s] if s != ds else -S[dr,s]
#                 for j in prange(s):
#                     dL_drs *= S[dr,j] if j != ds else C[dr,j]
#                 dL[dr,s] = dL_drs
#         # now set the diagonal, i.e. s = dr
#         dL_drs = 1.0
#         for j in prange(dr):
#             dL_drs *= S[dr,j] if j != ds else C[dr,j]
#         dL[dr,dr] = dL_drs
#
#     #return dL_arr
# Out:
# ---------------------------------------------------------------------------
# DistutilsExecError                        Traceback (most recent call last)
# ~/anaconda/envs/py3/lib/python3.6/distutils/unixccompiler.py in link(self, target_desc, objects, output_filename, output_dir, libraries, library_dirs, runtime_library_dirs, export_symbols, debug, extra_preargs, extra_postargs, build_temp, target_lang)
#     196
# --> 197                 self.spawn(linker + ld_args)
#     198             except DistutilsExecError as msg:
#
# ~/anaconda/envs/py3/lib/python3.6/distutils/ccompiler.py in spawn(self, cmd)
#     908     def spawn(self, cmd):
# --> 909         spawn(cmd, dry_run=self.dry_run)
#     910
#
# ~/anaconda/envs/py3/lib/python3.6/distutils/spawn.py in spawn(cmd, search_path, verbose, dry_run)
#      35     if os.name == 'posix':
# ---> 36         _spawn_posix(cmd, search_path, dry_run=dry_run)
#      37     elif os.name == 'nt':
#
# ~/anaconda/envs/py3/lib/python3.6/distutils/spawn.py in _spawn_posix(cmd, search_path, verbose, dry_run)
#     158                           "command %r failed with exit status %d"
# --> 159                           % (cmd, exit_status))
#     160             elif os.WIFSTOPPED(status):
#
# DistutilsExecError: command 'gcc' failed with exit status 1
#
# During handling of the above exception, another exception occurred:
#
# LinkError                                 Traceback (most recent call last)
# <ipython-input-16-b28b22accfaa> in <module>()
# ----> 1 get_ipython().run_cell_magic('cython', '--annotate --compile-args=-fopenmp --link-args=-gomp', '\nimport numpy as np\n\nimport cython\nfrom cython.parallel import prange\ncimport openmp\n\ncimport numpy as np\nfrom libc.math cimport sin, cos, pi\n\n#FLOAT64 = np.float64\nctypedef np.float64_t FLOAT64_t\n\n@cython.boundscheck(False)\n@cython.initializedcheck(False)  # turn off negative index wrapping for entire function\ndef initialize_trig_values(int dim,\n                           np.ndarray zeta,\n                           np.ndarray cos_zeta,\n                           np.ndarray sin_zeta):\n    \n    cdef FLOAT64_t [:, :] z = zeta\n    cdef FLOAT64_t [:, :] C = cos_zeta\n    cdef FLOAT64_t [:, :] S = sin_zeta\n    cdef int i, j\n    \n    with nogil:\n        for i in prange(dim):\n            for j in prange(i):\n                C[i,j] = cos(z[i,j])\n                S[i,j] = sin(z[i,j])\n            \n\n@cython.boundscheck(False)\n@cython.initializedcheck(False)  # wraparound: turn off negative index wrapping for entire function\ndef HyperSphere_lower_triangular(np.ndarray L_arr,\n                                 int dim,\n                                 np.ndarray cos_zeta,\n                                 np.ndarray sin_zeta):\n    \n    #cdef np.ndarray L_arr = np.zeros((dim, dim), dtype=FLOAT64)\n    # Memoryviews of the numpy arrays\n    cdef FLOAT64_t [:, :] L = L_arr\n    cdef FLOAT64_t [:, :] C = cos_zeta\n    cdef FLOAT64_t [:, :] S = sin_zeta\n\n    cdef int r, s, j\n    cdef FLOAT64_t L_rs\n    \n    with nogil:\n        L[0,0] = 1.0\n        for r in prange(dim):\n            L_rs = 1.0\n            for j in prange(r):\n                L_rs *= S[r,j]\n            L[r,r] = L_rs\n            for s in prange(r):\n                L_rs = C[r,s]\n                for j in prange(s):\n                    L_rs *= S[r,j]\n                L[r,s] = L_rs\n    #return L_arr\n    \n\n@cython.boundscheck(False)\n@cython.initializedcheck(False)  # turn off negative index wrapping for entire function\ndef HyperSphere_lower_triangular_derivative(np.ndarray dL_arr,\n                                            int dim,\n                                            int dr,\n                                            int ds,\n                                            np.ndarray cos_zeta,\n                                            np.ndarray sin_zeta):                                            \n    # Memoryviews of the numpy arrays\n    cdef FLOAT64_t [:, :] dL = dL_arr\n    cdef FLOAT64_t [:, :] C = cos_zeta\n    cdef FLOAT64_t [:, :] S = sin_zeta\n    \n    cdef FLOAT64_t dL_drs\n    cdef int r, s, j\n    \n    with nogil:\n        for s in prange(dr):\n            if ds <= s:\n                dL_drs = C[dr,s] if s != ds else -S[dr,s]\n                for j in prange(s):\n                    dL_drs *= S[dr,j] if j != ds else C[dr,j]\n                dL[dr,s] = dL_drs\n        # now set the diagonal, i.e. s = dr\n        dL_drs = 1.0 \n        for j in prange(dr):\n            dL_drs *= S[dr,j] if j != ds else C[dr,j]\n        dL[dr,dr] = dL_drs\n\n    #return dL_arr\n')
#
# ~/anaconda/envs/py3/lib/python3.6/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2101             magic_arg_s = self.var_expand(line, stack_depth)
#    2102             with self.builtin_trap:
# -> 2103                 result = fn(magic_arg_s, cell)
#    2104             return result
#    2105
#
# <decorator-gen-127> in cython(self, line, cell)
#
# ~/anaconda/envs/py3/lib/python3.6/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~/anaconda/envs/py3/lib/python3.6/site-packages/Cython/Build/IpythonMagic.py in cython(self, line, cell)
#     304             build_extension.build_temp = os.path.dirname(pyx_file)
#     305             build_extension.build_lib = lib_dir
# --> 306             build_extension.run()
#     307             self._code_cache[key] = module_name
#     308
#
# ~/anaconda/envs/py3/lib/python3.6/distutils/command/build_ext.py in run(self)
#     337
#     338         # Now actually compile and link everything.
# --> 339         self.build_extensions()
#     340
#     341     def check_extensions_list(self, extensions):
#
# ~/anaconda/envs/py3/lib/python3.6/distutils/command/build_ext.py in build_extensions(self)
#     446             self._build_extensions_parallel()
#     447         else:
# --> 448             self._build_extensions_serial()
#     449
#     450     def _build_extensions_parallel(self):
#
# ~/anaconda/envs/py3/lib/python3.6/distutils/command/build_ext.py in _build_extensions_serial(self)
#     471         for ext in self.extensions:
#     472             with self._filter_build_errors(ext):
# --> 473                 self.build_extension(ext)
#     474
#     475     @contextlib.contextmanager
#
# ~/anaconda/envs/py3/lib/python3.6/distutils/command/build_ext.py in build_extension(self, ext)
#     556             debug=self.debug,
#     557             build_temp=self.build_temp,
# --> 558             target_lang=language)
#     559
#     560     def swig_sources(self, sources, extension):
#
# ~/anaconda/envs/py3/lib/python3.6/distutils/ccompiler.py in link_shared_object(self, objects, output_filename, output_dir, libraries, library_dirs, runtime_library_dirs, export_symbols, debug, extra_preargs, extra_postargs, build_temp, target_lang)
#     715                   libraries, library_dirs, runtime_library_dirs,
#     716                   export_symbols, debug,
# --> 717                   extra_preargs, extra_postargs, build_temp, target_lang)
#     718
#     719
#
# ~/anaconda/envs/py3/lib/python3.6/distutils/unixccompiler.py in link(self, target_desc, objects, output_filename, output_dir, libraries, library_dirs, runtime_library_dirs, export_symbols, debug, extra_preargs, extra_postargs, build_temp, target_lang)
#     197                 self.spawn(linker + ld_args)
#     198             except DistutilsExecError as msg:
# --> 199                 raise LinkError(msg)
#     200         else:
#     201             log.debug("skipping %s (up-to-date)", output_filename)
#
# LinkError: command 'gcc' failed with exit status 1

# %%
from __future__ import print_function
from math import pi, sin, cos

import random
import timeit
import numpy
# Run the cell immediately above first
#import hypersphere_cython as hs

# =============================================================================
# Cythonize construction of matrices and gradient for efficiency
# =============================================================================
class HyperSphere(object):
    """Parameterizes the d-1-dimensional surface of a d-dimensional hypersphere
    using a lower triangular matrix with d*(d-1)/2 parameters, each in the 
    interval (0, pi).
    """
    def __init__(self, dim, zeta=[]):
        m = dim*(dim-1)//2
        self.dim = dim
        if isinstance(zeta, (list, tuple, np.ndarray)) and len(zeta):
            assert len(zeta) == m, "Expecting {0}*({0}-1)/2 elements".format(dim)
        elif isinstance(zeta, (int, float, np.float64, np.int64)):
            zeta = [zeta]
        else:
            zeta = [pi/4.0]*m
        zeta_lt = np.zeros((dim, dim))
        # lower triangular indices, offset -1 to get below-diagonal elements
        for z, ind in zip(zeta, zip(*np.tril_indices(dim, -1))):
            zeta_lt[ind] = z
        # set the diagonal to 1
        #np.fill_diagonal(zeta_lt.s, 1.0)

        self.zeta = zeta_lt
        
        # initialize trig values 
        self._cos_zeta = None
        self._sin_zeta = None
        self._initialize_trig_values()
        
        self._lt = None
        # CAUTION do not cache values at initialization without making sure
        # clone_with_theta will trigger their recalculation !
        #self._lt = self._lower_triangular()
       
    def _initialize_trig_values(self):
        cos_zeta = np.zeros((self.dim, self.dim), dtype=np.float64)
        sin_zeta = np.zeros((self.dim, self.dim), dtype=np.float64)
        
        initialize_trig_values(self.dim, self.zeta, cos_zeta, sin_zeta)
        
        self._cos_zeta = cos_zeta
        self._sin_zeta = sin_zeta
        
    @property
    def cos_zeta(self):
        return self._cos_zeta

    @property
    def sin_zeta(self):
        return self._sin_zeta

    # see HyperSphere_test for pure Python equivalent
    def _lower_triangular(self):
        if self._lt is None:
            lt = np.zeros((self.dim, self.dim))
            HyperSphere_lower_triangular(lt,
                                         self.dim,
                                         self.cos_zeta,
                                         self.sin_zeta)
            self._lt = lt
        return self._lt
    
    @property
    def correlation(self):
        lt = self._lower_triangular()
        corr = lt.dot(lt.T)
        # this is not strictly needed, 
        # but numerical error may cause some diagonal values to be
        # slightly off
        np.fill_diagonal(corr, 1.0)
        return corr

    # see HyperSphere_test for pure Python equivalent
    def _lower_triangular_derivative(self):
        dim = self.dim
        #zeta = self.zeta
        cos_zeta = self.cos_zeta
        sin_zeta = self.sin_zeta
        
        dLstack = []
        for dr, ds in zip(*np.tril_indices(dim, -1)):
            dL = np.zeros((dim, dim), dtype=np.float64)
            
            HyperSphere_lower_triangular_derivative(dL, dim, dr, ds,
                                                    cos_zeta, sin_zeta)
            dLstack.append(dL)
        return dLstack
    
    @property
    def gradient(self):
        L = self._lower_triangular()
        dLstack = self._lower_triangular_derivative()
        gradstack = []
        for dL in dLstack:
            dLLt = dL.dot(L.T)
            grad = dLLt + dLLt.T
            gradstack.append(grad)
        return gradstack

# %%
# =============================================================================
# Pure Python implememntation, compare to Cython version for testing
# =============================================================================
class HyperSphere_pure(HyperSphere):
    """Parameterizes the d-1-dimensional surface of a d-dimensional hypersphere
    using a lower triangular matrix with d*(d-1)/2 parameters, each in the 
    interval (0, pi).
    """
    def __init__(self, dim, zeta=[]):
        m = dim*(dim-1)//2
        self.dim = dim
        if isinstance(zeta, (list, tuple)) and len(zeta):
            assert len(zeta) == m, "Expecting {0}*({0}-1)/2 elements".format(dim)
        elif isinstance(zeta, (int, float, np.float64, np.int64)):
            zeta = [zeta]
        else:
            zeta = [pi/4.0]*m
        zeta_lt = np.zeros((dim, dim))
        # lower triangular indices, offset -1 to get below-diagonal elements
        for th, ind in zip(zeta, zip(*np.tril_indices(dim,-1))):
            zeta_lt[ind] = th
        # set the diagonal to 1
        for i in range(dim):
            zeta_lt[i,i] = 1.0
        self.zeta = zeta_lt
        self._lt = None
        #self._lt = self._lower_triangular()
            
    def _lower_triangular(self):
        if self._lt is None:
            dim = self.dim
            zeta = self.zeta
            L = np.zeros((dim, dim), dtype=np.float64)
            # auxilary array to avoid recomputing sin
            sin_r = np.zeros(dim, dtype=np.float64)
            for r in range(dim):
                L_rr = 1.0
                for j in range(r):
                    sin_rj = sin(zeta[r,j])
                    sin_r[j] = sin_rj
                    L_rr *= sin_rj
                L[r,r] = L_rr
                for s in range(r):
                    L_rs = cos(zeta[r,s])
                    for j in range(s):
                        L_rs *= sin_r[j]
                    L[r,s] = L_rs
            self._lt = L
        return self._lt
    
#    @property
#    def correlation(self):
#        lt = self._lower_triangular()
#        return lt.dot(lt.T)

    def _lower_triangular_derivative(self):
        dim = self.dim
        zeta = self.zeta
        #dL[0,0] = 0.0
        dLstack = []
        # auxiliary arrays to avoid recomputing trig functions
        C = np.zeros((dim, dim), dtype=np.float64)
        S = np.zeros((dim, dim), dtype=np.float64)
        for r, s in zip(*np.tril_indices(dim, -1)):
            zeta_rs = zeta[r,s]
            C[r,s] = cos(zeta_rs)
            S[r,s] = sin(zeta_rs)
        for dr, ds in zip(*np.tril_indices(dim, -1)):
            dL = np.zeros((dim, dim), dtype=np.float64)
            for s in range(dr):
                if ds <= s:
                    dL_drs = C[dr,s] if s != ds else -S[dr,s]
                    for j in range(s):
                        dL_drs *= S[dr,j] if j != ds else C[dr,j]
                    dL[dr,s] = dL_drs
            # now set the diagonal, i.e. s = dr
            dL_drs = 1.0
            for j in range(dr):
                dL_drs *= S[dr,j] if j != ds else C[dr,j]
            dL[dr,dr] = dL_drs
            dLstack.append(dL)
        return dLstack

# %%
def test_correlation(dim, pure=True):
    m = dim*(dim-1)//2
    zeta = np.array([random.uniform(0, pi) for i in range(m)])
    h = HyperSphere_pure(dim, zeta) if pure else HyperSphere(dim, zeta)
    return h.correlation
    
def test_gradient(dim, pure=True):
    m = dim*(dim-1)//2
    zeta = np.array([random.uniform(0, pi) for i in range(m)])
    h = HyperSphere_pure(dim, zeta) if pure else HyperSphere(dim, zeta)
    return h.gradient

# %%
# %matplotlib

import pandas as pd
import seaborn as sns

from collections import defaultdict

template = "{:3} {:6} {:11} {:10.3f} sec, {:15.9f} usec per repetition"

hc = HyperSphere(6)
hp = HyperSphere_pure(6)
#ho = HyperSphere_pure_original(4)

print("\nChecking Correlation for equivalence to pure python")
diff = hc.correlation - hp.correlation
print(diff.min(), diff.max())
print("should be zero")
print("\nChecking Gradient for equivalence to pure python")
for gc, gp in zip(hc.gradient, hp.gradient):
    diff = gc - gp
    print(diff.min(), diff.max())
print("All should be zero")
# Out:
# Using matplotlib backend: MacOSX
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-7c67971c1dd9> in <module>()
#       8 template = "{:3} {:6} {:11} {:10.3f} sec, {:15.9f} usec per repetition"
#       9
# ---> 10 hc = HyperSphere(6)
#      11 hp = HyperSphere_pure(6)
#      12 #ho = HyperSphere_pure_original(4)
#
# NameError: name 'HyperSphere' is not defined
# ERROR:tornado.application:Exception in callback functools.partial(<function wrap.<locals>.null_wrapper at 0x1125d08c8>)
# Traceback (most recent call last):
#   File "/Users/johnbauer/anaconda/envs/py3/lib/python3.6/site-packages/tornado/ioloop.py", line 605, in _run_callback
#     ret = callback()
#   File "/Users/johnbauer/anaconda/envs/py3/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/johnbauer/anaconda/envs/py3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 265, in enter_eventloop
#     self.eventloop(self)
#   File "/Users/johnbauer/anaconda/envs/py3/lib/python3.6/site-packages/ipykernel/eventloops.py", line 277, in loop_cocoa
#     show.mainloop()
# AttributeError: 'function' object has no attribute 'mainloop'

# %%
def test(function, dimension, pure, N):

    test = "test_{}({}, pure={})".format(function, dimension, pure)
    time = timeit.timeit(test,
                           setup="from __main__ import test_{}".format(function),
                           number=N)
    return dict(function=function, dimension=dimension,
                code="Python" if pure else "Cython",
                N=N,
                time=time)

class TimeitData():
    def __init__(self):
        self.data = defaultdict(list)

    def add_result(self, result_dict):
        data = self.data
        for k, v in result_dict.items():
            data[k].append(v)

    @property
    def dataframe(self):
        return pd.DataFrame(self.data)

td = TimeitData()

N = 200
max_dim = 31 # was 61; suppress test code when set to 2

usec = 1e6 / N

for d in range(2,max_dim):
    for f in ["correlation", "gradient"]:
        for pure in [False, True]:
            result_dict = test(f, d, pure, N)
            time = result_dict["time"]
            print(template.format(d,
                                  "Python" if pure else "Cython",
                                  f,
                                  time,
                                  time*usec))
            td.add_result(result_dict)

# read cached data if tests are suppressed
if max_dim == 2:
    df = pd.read_csv("HyperSphere_test_60.csv")
else:
    df = td.dataframe

df["color"] = df.code.replace(["Cython", "Python"], ["r", "b"])
df['parameters'] = df.dimension * (df.dimension - 1) / 2

df_corr = df[df.function == "correlation"]
df_grad = df[df.function == "gradient"]

df_corr.plot.scatter('dimension', 'time', c=df.color, title='Correlation')
df_grad.plot.scatter('dimension', 'time', c=df.color, title='Gradient')

df_corr.plot.scatter('parameters', 'time', c=df.color, title='Correlation')
df_grad.plot.scatter('parameters', 'time', c=df.color, title='Gradient')

sns.lmplot(x='dimension', y='time', data=df_corr, order=2, hue="code")
sns.lmplot(x='dimension', y='time', data=df_grad, order=2, hue="code")

sns.lmplot(x='parameters', y='time', data=df_corr, order=2, hue="code")
sns.lmplot(x='parameters', y='time', data=df_grad, order=2, hue="code")

df_corr_cython = df_corr[df_corr.code == 'Cython']
df_corr_python = df_corr[df_corr.code == 'Python']

df_corr_cython.index = range(len(df_corr_cython))
df_corr_python.index = range(len(df_corr_python))

df_corr_compare = pd.concat([df_corr_cython, df_corr_python], keys=['cython', 'python'], axis=1)
df_corr_compare['ratio'] = df_corr_compare[('python', 'time')] / df_corr_compare[('cython', 'time')]

df_grad_cython = df_grad[df_grad.code == 'Cython']
df_grad_python = df_grad[df_grad.code == 'Python']

df_grad_cython.index = range(len(df_grad_cython))
df_grad_python.index = range(len(df_grad_python))

df_grad_compare = pd.concat([df_grad_cython, df_grad_python], keys=['cython', 'python'], axis=1)
df_grad_compare['ratio'] = df_grad_compare[('python', 'time')] / df_grad_compare[('cython', 'time')]


df_corr_ratio = pd.DataFrame({ 'ratio' : df_corr_compare['ratio'], 'parameters' : df_corr_compare[('cython', 'parameters')]})
df_grad_ratio = pd.DataFrame({ 'ratio' : df_grad_compare['ratio'], 'parameters' : df_grad_compare[('cython', 'parameters')]})

sns.lmplot(x='parameters', y='ratio', data=df_corr_ratio, order=4)
sns.lmplot(x='parameters', y='ratio', data=df_grad_ratio, order=4)
# Out:
#   2 Cython correlation      0.021 sec,   104.001185000 usec per repetition
#   2 Python correlation      0.014 sec,    70.361784997 usec per repetition
#   2 Cython gradient         0.024 sec,   118.949954999 usec per repetition
#   2 Python gradient         0.023 sec,   113.014780004 usec per repetition
#   3 Cython correlation      0.013 sec,    63.479060000 usec per repetition
#   3 Python correlation      0.021 sec,   102.945435001 usec per repetition
#   3 Cython gradient         0.018 sec,    92.185090002 usec per repetition
#   3 Python gradient         0.023 sec,   117.126099999 usec per repetition
#   4 Cython correlation      0.009 sec,    43.212005003 usec per repetition
#   4 Python correlation      0.012 sec,    57.746215002 usec per repetition
#   4 Cython gradient         0.019 sec,    95.255850001 usec per repetition
#   4 Python gradient         0.027 sec,   136.005515001 usec per repetition
#   5 Cython correlation      0.010 sec,    49.305670000 usec per repetition
#   5 Python correlation      0.018 sec,    92.364259999 usec per repetition
#   5 Cython gradient         0.050 sec,   250.035165000 usec per repetition
#   5 Python gradient         0.048 sec,   238.207810003 usec per repetition
#   6 Cython correlation      0.012 sec,    60.189675000 usec per repetition
#   6 Python correlation      0.015 sec,    73.932164996 usec per repetition
#   6 Cython gradient         0.033 sec,   164.131920001 usec per repetition
#   6 Python gradient         0.071 sec,   354.417545000 usec per repetition
#   7 Cython correlation      0.013 sec,    66.558220001 usec per repetition
#   7 Python correlation      0.019 sec,    93.609554997 usec per repetition
#   7 Cython gradient         0.040 sec,   200.814944997 usec per repetition
#   7 Python gradient         0.125 sec,   622.764984996 usec per repetition
#   8 Cython correlation      0.018 sec,    88.721745001 usec per repetition
#   8 Python correlation      0.029 sec,   144.153289998 usec per repetition
#   8 Cython gradient         0.064 sec,   319.494719997 usec per repetition
#   8 Python gradient         0.121 sec,   604.286819998 usec per repetition
#   9 Cython correlation      0.017 sec,    85.122794999 usec per repetition
#   9 Python correlation      0.026 sec,   127.772810001 usec per repetition
#   9 Cython gradient         0.095 sec,   475.347295001 usec per repetition
#   9 Python gradient         0.171 sec,   856.098720001 usec per repetition
#  10 Cython correlation      0.025 sec,   127.202495000 usec per repetition
#  10 Python correlation      0.033 sec,   163.153929998 usec per repetition
#  10 Cython gradient         0.093 sec,   463.972040002 usec per repetition
#  10 Python gradient         0.236 sec,  1178.317419999 usec per repetition
#  11 Cython correlation      0.021 sec,   105.859640003 usec per repetition
#  11 Python correlation      0.032 sec,   161.405310000 usec per repetition
#  11 Cython gradient         0.112 sec,   559.184164999 usec per repetition
#  11 Python gradient         0.288 sec,  1439.505225003 usec per repetition
#  12 Cython correlation      0.022 sec,   108.120235000 usec per repetition
#  12 Python correlation      0.042 sec,   210.896875001 usec per repetition
#  12 Cython gradient         0.155 sec,   776.117529999 usec per repetition
#  12 Python gradient         0.354 sec,  1770.941250002 usec per repetition
#  13 Cython correlation      0.021 sec,   104.645965002 usec per repetition
#  13 Python correlation      0.043 sec,   217.199439999 usec per repetition
#  13 Cython gradient         0.177 sec,   885.985785003 usec per repetition
#  13 Python gradient         0.415 sec,  2073.188800000 usec per repetition
#  14 Cython correlation      0.021 sec,   107.337195000 usec per repetition
#  14 Python correlation      0.056 sec,   278.409150001 usec per repetition
#  14 Cython gradient         0.184 sec,   918.666450002 usec per repetition
#  14 Python gradient         0.531 sec,  2657.465259999 usec per repetition
#  15 Cython correlation      0.024 sec,   121.653964998 usec per repetition
#  15 Python correlation      0.071 sec,   352.803054998 usec per repetition
#  15 Cython gradient         0.248 sec,  1238.575355001 usec per repetition
#  15 Python gradient         0.677 sec,  3385.510270000 usec per repetition
#  16 Cython correlation      0.026 sec,   128.053449998 usec per repetition
#  16 Python correlation      0.066 sec,   329.861920000 usec per repetition
#  16 Cython gradient         0.288 sec,  1439.938264998 usec per repetition
#  16 Python gradient         0.878 sec,  4389.965870000 usec per repetition
#  17 Cython correlation      0.041 sec,   206.756520001 usec per repetition
#  17 Python correlation      0.073 sec,   367.430800002 usec per repetition
#  17 Cython gradient         0.312 sec,  1561.658930000 usec per repetition
#  17 Python gradient         1.151 sec,  5755.098510003 usec per repetition
#  18 Cython correlation      0.030 sec,   152.140205000 usec per repetition
#  18 Python correlation      0.094 sec,   469.058664999 usec per repetition
#  18 Cython gradient         0.386 sec,  1930.822274999 usec per repetition
#  18 Python gradient         1.300 sec,  6497.831849997 usec per repetition
#  19 Cython correlation      0.047 sec,   236.342730000 usec per repetition
#  19 Python correlation      0.106 sec,   530.240900002 usec per repetition
#  19 Cython gradient         0.485 sec,  2422.803935001 usec per repetition
#  19 Python gradient         1.592 sec,  7958.826350000 usec per repetition
#  20 Cython correlation      0.046 sec,   232.396050001 usec per repetition
#  20 Python correlation      0.140 sec,   698.566985002 usec per repetition
#  20 Cython gradient         0.516 sec,  2580.998380004 usec per repetition
#  20 Python gradient         1.955 sec,  9774.855265000 usec per repetition
#  21 Cython correlation      0.048 sec,   238.982144997 usec per repetition
#  21 Python correlation      0.142 sec,   709.946989996 usec per repetition
#  21 Cython gradient         0.595 sec,  2975.560494997 usec per repetition
#  21 Python gradient         2.222 sec, 11109.783950001 usec per repetition
#  22 Cython correlation      0.052 sec,   260.465920001 usec per repetition
#  22 Python correlation      0.125 sec,   625.899619999 usec per repetition
#  22 Cython gradient         0.572 sec,  2861.072699998 usec per repetition
#  22 Python gradient         2.449 sec, 12247.108840002 usec per repetition
#  23 Cython correlation      0.048 sec,   241.439034999 usec per repetition
#  23 Python correlation      0.149 sec,   745.120204997 usec per repetition
#  23 Cython gradient         0.817 sec,  4084.807905001 usec per repetition
#  23 Python gradient         2.891 sec, 14455.455455000 usec per repetition
#  24 Cython correlation      0.051 sec,   254.140705001 usec per repetition
#  24 Python correlation      0.159 sec,   793.432754999 usec per repetition
#  24 Cython gradient         0.724 sec,  3620.474664999 usec per repetition
#  24 Python gradient         3.488 sec, 17441.121064999 usec per repetition
#  25 Cython correlation      0.052 sec,   260.355129999 usec per repetition
#  25 Python correlation      0.177 sec,   884.548959998 usec per repetition
#  25 Cython gradient         0.800 sec,  3999.783605000 usec per repetition
#  25 Python gradient         3.480 sec, 17401.624325003 usec per repetition
#  26 Cython correlation      0.056 sec,   279.455344998 usec per repetition
#  26 Python correlation      0.192 sec,   958.046924998 usec per repetition
#  26 Cython gradient         1.055 sec,  5274.872120003 usec per repetition
#  26 Python gradient         4.092 sec, 20460.288155000 usec per repetition
#  27 Cython correlation      0.056 sec,   280.976320000 usec per repetition
#  27 Python correlation      0.197 sec,   985.977045002 usec per repetition
#  27 Cython gradient         1.009 sec,  5045.201519997 usec per repetition
#  27 Python gradient         4.691 sec, 23456.215295000 usec per repetition
#  28 Cython correlation      0.062 sec,   312.167985003 usec per repetition
#  28 Python correlation      0.237 sec,  1186.809169999 usec per repetition
#  28 Cython gradient         1.326 sec,  6628.570440002 usec per repetition
#  28 Python gradient         6.321 sec, 31607.206644999 usec per repetition
#  29 Cython correlation      0.071 sec,   352.673010002 usec per repetition
#  29 Python correlation      0.343 sec,  1712.790855004 usec per repetition
#  29 Cython gradient         1.747 sec,  8732.639724999 usec per repetition
#  29 Python gradient         6.223 sec, 31117.207699999 usec per repetition
#  30 Cython correlation      0.084 sec,   419.845135002 usec per repetition
#  30 Python correlation      0.301 sec,  1506.689470002 usec per repetition
#  30 Cython gradient         1.785 sec,  8924.115455002 usec per repetition
#  30 Python gradient         7.129 sec, 35643.889700000 usec per repetition
